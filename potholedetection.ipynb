# %% [markdown]
# # Set-Up

# %%
import os

# %%
# !nvidia-smi
# Out:
# Sat May 30 03:44:11 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8             16W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !python -m pip install --upgrade pip

# %%
# !pip install opencv-python

# %%
# !pip install ultralytics

# %%
# !python -c "from ultralytics import YOLO; print('YOLOv8 OK')"

# %%
# !python -c "import torch; print(torch.cuda.is_available(), torch.cuda.get_device_name(0))"
# Out:
# True Tesla T4

# %%
# !pip install roboflow

# %%
# !pip install matplotlib Pillow

# %%
# !pip install pandas numpy scikit-learn tqdm

# %% [markdown]
# #Git Cloning

# %%
# !git clone https://github.com/jampanirohith/Smart-Suspension
# Out:
# fatal: destination path 'Smart-Suspension' already exists and is not an empty directory.

# %% [markdown]
# #Dataset Downloading

# %%
import shutil

folder_path = '/content/sample_data'
shutil.rmtree(folder_path)
print("Folder deleted successfully")
# Out:
# Folder deleted successfully

# %%
# !python /content/Smart-Suspension/setup/download_dataset.py

# %% [markdown]
# #Training the model

# %%
# !python /content/Smart-Suspension/train.py

# %% [markdown]
# #Testing the model

# %%
# !python /content/Smart-Suspension/videodetect.py
